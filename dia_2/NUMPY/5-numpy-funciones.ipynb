# %% [markdown]
# # FUNCIONES MAS COMUNES EN NUMPY

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[9, 7],
#        [9, 2],
#        [8, 1]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[9, 7, 9, 2, 8, 1]])

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 4, 15, 15,  4,  9, 11, 19,  8,  1, 19])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 4, 15, 15,  4,  9],
#        [11, 19,  8,  1, 19]])

# %%
arr.max()
# Out:
# np.int64(19)

# %%
matriz.max()
# Out:
# np.int64(19)

# %%
arr.argmax()
# Out:
# np.int64(6)

# %%
matriz.argmax()
# Out:
# np.int64(6)

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# np.int64(1)

# %%
matriz.min()
# Out:
# np.int64(1)

# %%
matriz.min(0)
# Out:
# array([ 4, 15,  8,  1,  9])

# %%
matriz.min(1)
# Out:
# array([4, 1])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([ 4, 15, 15,  4,  9, 11, 19,  8,  1, 19])

# %%
arr.sort()
arr
# Out:
# array([ 1,  4,  4,  8,  9, 11, 15, 15, 19, 19])

# %%
arr2 = arr[::-1]
arr2
# Out:
# array([19, 19, 15, 15, 11,  9,  8,  4,  4,  1])
